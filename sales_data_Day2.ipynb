# %% [markdown]
# <a href="https://colab.research.google.com/github/allunanda12/data-analytics-practice/blob/main/sales_data_Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
profit = [
    4.56,
    4390.367,
    -53.8096,
    803.4705,
    -24.03,
    -37.03,
    -0.71,
    -59.82,
    261.8757,
    2.63,
    652.7331,
    314.4813,
    -114.64,
    384.38,
    -17.49,
    -114.64,
    -28.2968,
    -5.3072,
    8.894,
    144.69,
    -35.8788,
    209.997,
    3568.096,
    -84.4376,
    24.312,
    25.91382,
    162.666,
    -6923.6,
    -67.49,
    19.6282
]
region = [
    "West",
    "West",
    "East",
    "Central",
    "Central",
    "Central",
    "Central",
    "East",
    "East",
    "East",
    "East",
    "West",
    "West",
    "East",
    "East",
    "East",
    "West",
    "West",
    "West",
    "West",
    "West",
    "West",
    "West",
    "West",
    "West",
    "West",
    "West",
    "West",
    "West",
    "East"
]
sales = [
    13.01,
    6362.85,
    211.15,
    1164.45,
    22.23,
    13.99,
    14.26,
    33.47,
    379.53,
    18.8,
    945.99,
    455.77,
    231.79,
    1876.69,
    293.06,
    914.29,
    67.49,
    2.25,
    54.78,
    424.68,
    40.17,
    783.55,
    3838.14,
    58.68,
    53.1,
    647.07,
    627.04,
    3267.55,
    110.19,
    73.55
]
print("avg of profit",np.mean(profit))
print("medium profit",np.median(profit))
print("std of profit",np.std(profit))
print("avg of sales",np.mean(sales))
print("medium sales",np.median(sales))
print("std of sales",np.std(sales))
print("min of profit",np.min(profit))
print("max of profit",np.max(profit))
print("min of sales",np.min(sales))
print("max of sales",np.max(sales))
plt.boxplot(profit)
plt.show()
plt.bar(x=region,height=profit)
plt.show()
# Out:
# avg of profit 113.71715400000002
# medium profit 3.5949999999999998
# std of profit 1644.0177881340978
# avg of sales 766.6523333333332
# medium sales 221.47
# std of sales 1378.982621224027
# min of profit -6923.6
# max of profit 4390.367
# min of sales 2.25
# max of sales 6362.85
